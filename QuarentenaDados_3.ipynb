# %% [markdown]
# # Aula 3

# %%
import pandas as pd
imdb = pd.read_csv("/home/pinguim/Documentos/MeusEstudos/QuarentenaDados/movie_metadata.csv")
imdb.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
imdb["color"].unique()
# Out:
# array(['Color', nan, ' Black and White'], dtype=object)

# %%
imdb["color"].value_counts()
# Out:
# Color               4815
#  Black and White     209
# Name: color, dtype: int64

# %%
imdb["color"].value_counts(normalize=True)
# Out:
# Color               0.9584
#  Black and White    0.0416
# Name: color, dtype: float64

# %%
imdb["director_name"].value_counts()
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Clint Eastwood      20
# Martin Scorsese     20
# Ridley Scott        17
#                     ..
# Susanne Bier         1
# Mic Rodgers          1
# Herb Freed           1
# David Oelhoffen      1
# Jane Clark           1
# Name: director_name, Length: 2398, dtype: int64

# %%
imdb["num_critic_for_reviews"]
# Out:
# 0       723.0
# 1       302.0
# 2       602.0
# 3       813.0
# 4         NaN
#         ...
# 5038      1.0
# 5039     43.0
# 5040     13.0
# 5041     14.0
# 5042     43.0
# Name: num_critic_for_reviews, Length: 5043, dtype: float64

# %%
imdb["num_critic_for_reviews"].describe()
# Out:
# count    4993.000000
# mean      140.194272
# std       121.601675
# min         1.000000
# 25%        50.000000
# 50%       110.000000
# 75%       195.000000
# max       813.000000
# Name: num_critic_for_reviews, dtype: float64

# %%
import seaborn as sns
sns.set_style("whitegrid")
imdb["num_critic_for_reviews"].plot(kind="hist")

# %%
imdb["gross"].hist()

# %%
imdb.sort_values("gross", ascending=False).head()
# Out:
#      color    director_name  num_critic_for_reviews  duration  \
# 0    Color    James Cameron                   723.0     178.0
# 26   Color    James Cameron                   315.0     194.0
# 29   Color  Colin Trevorrow                   644.0     124.0
# 794  Color      Joss Whedon                   703.0     173.0
# 17   Color      Joss Whedon                   703.0     173.0
#
#      director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                        0.0                   855.0   Joel David Moore
# 26                       0.0                   794.0       Kate Winslet
# 29                     365.0                  1000.0         Judy Greer
# 794                      0.0                 19000.0  Robert Downey Jr.
# 17                       0.0                 19000.0  Robert Downey Jr.
#
#      actor_1_facebook_likes        gross                            genres  \
# 0                    1000.0  760505847.0   Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
color_or_bw = imdb.query("color in ['Color', ' Black and White']")
color_or_bw["color_0_ou_1"] = (color_or_bw["color"]=="Color") * 1
color_or_bw["color_0_ou_1"].value_counts()
# Out:
# /home/pinguim/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1    4815
# 0     209
# Name: color_0_ou_1, dtype: int64

# %%
color_or_bw.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 5                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
sns.scatterplot(data=color_or_bw, x="color_0_ou_1", y="gross")

# %%
color_or_bw.groupby("color").mean()["gross"]
# Out:
# color
#  Black and White    3.245702e+07
# Color               4.902619e+07
# Name: gross, dtype: float64

# %%
color_or_bw.groupby("color").mean()["imdb_score"]
# Out:
# color
#  Black and White    7.227273
# Color               6.409533
# Name: imdb_score, dtype: float64

# %%
color_or_bw.groupby("color").median()["imdb_score"]
# Out:
# color
#  Black and White    7.4
# Color               6.5
# Name: imdb_score, dtype: float64

# %%
budget_gross = imdb[["budget", "gross"]].dropna().query("budget > 0 | gross > 0")

sns.scatterplot(data=budget_gross, x="budget", y="gross")

# %%
imdb.sort_values("budget", ascending=False).head(10)
# Out:
#       color    director_name  num_critic_for_reviews  duration  \
# 2988  Color     Joon-ho Bong                   363.0     110.0
# 3859  Color   Chan-wook Park                   202.0     112.0
# 3005  Color     Lajos Koltai                    73.0     134.0
# 2323  Color   Hayao Miyazaki                   174.0     134.0
# 2334  Color  Katsuhiro Ôtomo                   105.0     103.0
# 3423  Color  Katsuhiro Ôtomo                   150.0     124.0
# 4542  Color    Takao Okawara                   107.0      99.0
# 3075  Color      Karan Johar                    20.0     193.0
# 3851  Color     Carlos Saura                    35.0     115.0
# 3273  Color      Anurag Basu                    41.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes            actor_2_name  \
# 2988                    584.0                    74.0            Kang-ho Song
# 3859                      0.0                    38.0            Yeong-ae Lee
# ...

# %%
imdb["country"].unique()
# Out:
# array(['USA', 'UK', nan, 'New Zealand', 'Canada', 'Australia', 'Belgium',
#        'Japan', 'Germany', 'China', 'France', 'New Line', 'Mexico',
#        'Spain', 'Hong Kong', 'Czech Republic', 'India', 'Soviet Union',
#        'South Korea', 'Peru', 'Italy', 'Russia', 'Aruba', 'Denmark',
#        'Libya', 'Ireland', 'South Africa', 'Iceland', 'Switzerland',
#        'Romania', 'West Germany', 'Chile', 'Netherlands', 'Hungary',
#        'Panama', 'Greece', 'Sweden', 'Norway', 'Taiwan', 'Official site',
#        'Cambodia', 'Thailand', 'Slovakia', 'Bulgaria', 'Iran', 'Poland',
#        'Georgia', 'Turkey', 'Nigeria', 'Brazil', 'Finland', 'Bahamas',
#        'Argentina', 'Colombia', 'Israel', 'Egypt', 'Kyrgyzstan',
#        'Indonesia', 'Pakistan', 'Slovenia', 'Afghanistan',
#        'Dominican Republic', 'Cameroon', 'United Arab Emirates', 'Kenya',
#        'Philippines'], dtype=object)

# %%
imdb = imdb.drop_duplicates()
imdb_usa = imdb.query("country == 'USA'")
imdb_usa.sort_values("budget", ascending=False).head(10)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 1     Color     Gore Verbinski                   302.0     169.0
# 5     Color     Andrew Stanton                   462.0     132.0
# 7     Color       Nathan Greno                   324.0     100.0
# 6     Color          Sam Raimi                   392.0     156.0
# 3461  Color          Sam Raimi                   392.0     156.0
# 18    Color       Rob Marshall                   448.0     136.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 8     Color        Joss Whedon                   635.0     141.0
# 10    Color        Zack Snyder                   673.0     183.0
# 27    Color      Anthony Russo                   516.0     147.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 1                       563.0                  1000.0       Orlando Bloom
# 5                       475.0                   530.0     Samantha Morton
# ...

# %%
budget_gross = imdb_usa[["budget", "gross"]].dropna().query("budget > 0 | gross > 0")

sns.scatterplot(data = budget_gross, x="budget", y="gross")

# %%
imdb_usa["lucro"] = imdb_usa["gross"] - imdb_usa["budget"]
budget_gross = imdb_usa.query("budget >0 | gross > 0")[["budget", "lucro"]].dropna()
sns.scatterplot(data = budget_gross, x="budget", y="lucro")
# Out:
# /home/pinguim/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
budget_gross = imdb_usa.query("budget >0 | gross > 0")[["title_year", "lucro"]].dropna()
sns.scatterplot(data = budget_gross, x="title_year", y="lucro")

# %%
filmes_por_diretor = imdb_usa["director_name"].value_counts()
gross_director = imdb_usa[["director_name", "gross"]].set_index("director_name").join(filmes_por_diretor, on="director_name")
gross_director.columns=["dindin", "filmes_irmaos"]
gross_director = gross_director.reset_index()
gross_director.head(10)
# Out:
#        director_name       dindin  filmes_irmaos
# 0      James Cameron  760505847.0            6.0
# 1     Gore Verbinski  309404152.0            7.0
# 2  Christopher Nolan  448130642.0            8.0
# 3     Andrew Stanton   73058679.0            3.0
# 4          Sam Raimi  336530303.0           11.0
# 5       Nathan Greno  200807262.0            1.0
# 6        Joss Whedon  458991599.0            3.0
# 7        Zack Snyder  330249062.0            8.0
# 8       Bryan Singer  200069408.0            7.0
# 9     Gore Verbinski  423032628.0            7.0

# %%
sns.scatterplot(data=gross_director, x="filmes_irmaos", y="dindin")

# %%
sns.pairplot(data=imdb_usa[["gross", "budget", "lucro", "title_year"]])

# %%
imdb_usa[["gross", "budget", "lucro", "title_year"]].corr()
# Out:
#                gross    budget     lucro  title_year
# gross       1.000000  0.645673  0.797037    0.034827
# budget      0.645673  1.000000  0.053455    0.229453
# lucro       0.797037  0.053455  1.000000   -0.123035
# title_year  0.034827  0.229453 -0.123035    1.000000

# %% [markdown]
# ## Desafio 1 do [Thiago Gonçalves](https://twitter.com/tgcsantos)
#
# Plotar e analisar o Boxplot da média (coluna imbd_score) dos filmes em preto e branco e coloridos.

# %%
sns.boxplot(data=imdb, x="color", y="imdb_score")

# %% [markdown]
# Observa-se que os filmes em pretp e branco tem uma média de votos mais alta do que os coloridos, além de um número menor de outliers.

# %% [markdown]
# ## Desafio 2 do [Guilherme Silveira](https://twitter.com/guilhermecaelum)
#
# No gráfico de **budget por lucro** temos um ponto com muito custo e prejuizo, descubra com é esse filme (budget próximo de 2.5).

# %%
budget_gross.sort_values("lucro", ascending=False).tail()
# Out:
#     title_year        lucro
# 49      2013.0 -129828140.0
# 85      2013.0 -136702695.0
# 28      2012.0 -143826840.0
# 91      2004.0 -164334574.0
# 5       2012.0 -190641321.0

# %%
imdb_usa[["movie_title", "title_year", "gross", "budget", "lucro"]].sort_values("lucro", ascending=False).dropna().tail()
# Out:
#                movie_title  title_year       gross       budget        lucro
# 49  Jack the Giant Slayer       2013.0  65171860.0  195000000.0 -129828140.0
# 85               47 Ronin       2013.0  38297305.0  175000000.0 -136702695.0
# 28             Battleship       2012.0  65173160.0  209000000.0 -143826840.0
# 91      The Polar Express       2004.0    665426.0  165000000.0 -164334574.0
# 5             John Carter       2012.0  73058679.0  263700000.0 -190641321.0

# %% [markdown]
# Utilizando os dados do dataset budget_gross que foi o utilizado no gráfico budget por lucro, e utilizando o método tail para observarmos as últimas posições que retratam exatamente valores negativos nos lucros, podemos inferir o filme John Carter como sendo o filme com custo muito elevado não conseguindo recuperar em forma de lucro.

# %% [markdown]
# ## Desafio 3 do [Guilherme Silveira](https://twitter.com/guilhermecaelum)
#
# Em aula falamos que talvez, filmes mais recentes podem ter prejuizo pois ainda não tiveram tempo de recuperar o investimento. Analise essas informações e nos conte quais foram suas conclusões.

# %%
imdb_usa[["director_name", "movie_title", "title_year", "gross", "budget", "lucro"]].query("title_year>=2000").sort_values("lucro", ascending=False).dropna().head(100)
# Out:
#           director_name              movie_title  title_year        gross  \
# 0         James Cameron                  Avatar       2009.0  760505847.0
# 29      Colin Trevorrow          Jurassic World       2015.0  652177271.0
# 17          Joss Whedon            The Avengers       2012.0  623279547.0
# 66    Christopher Nolan         The Dark Knight       2008.0  533316061.0
# 439           Gary Ross        The Hunger Games       2012.0  407999255.0
# ...                 ...                      ...         ...          ...
# 3583      Michael Moore         Fahrenheit 9/11       2004.0  119078393.0
# 2947         Josh Boone  The Fault in Our Stars       2014.0  124868837.0
# 650        Nancy Meyers         What Women Want       2000.0  182805123.0
# 508          Ron Howard        A Beautiful Mind       2001.0  170708996.0
# 911    Steven Spielberg     Catch Me If You Can       2002.0  164435221.0
#
#            budget        lucro
# 0     237000000.0  523505847.0
# ...

# %%
imdb_usa[["director_name", "movie_title", "title_year", "gross", "budget", "lucro"]].query("title_year>=2010").sort_values("lucro", ascending=False).dropna().head(100)
# Out:
#            director_name                       movie_title  title_year  \
# 29       Colin Trevorrow                   Jurassic World       2015.0
# 17           Joss Whedon                     The Avengers       2012.0
# 439            Gary Ross                 The Hunger Games       2012.0
# 812           Tim Miller                         Deadpool       2016.0
# 186     Francis Lawrence  The Hunger Games: Catching Fire       2013.0
# ...                  ...                               ...         ...
# 402   Genndy Tartakovsky               Hotel Transylvania       2012.0
# 296    Quentin Tarantino                 Django Unchained       2012.0
# 1576     Robert Zemeckis                           Flight       2012.0
# 2171     Alexander Payne                  The Descendants       2011.0
# 3288      James DeMonaco               The Purge: Anarchy       2014.0
#
#             gross       budget        lucro
# 29    652177271.0  150000000.0  502177271.0
# ...

# %%
imdb_usa[["director_name", "movie_title", "title_year", "gross", "budget", "lucro"]].query("title_year>=2015").sort_values("lucro", ascending=False).dropna().tail(50)
# Out:
#               director_name  \
# 2888         Mark Neveldine
# 2286          John Hillcoat
# 3893           Henry Hobson
# 372          Chris Columbus
# 2333    Angelina Jolie Pitt
# 3015          Timothy Hines
# 2549        Cyrus Nowrasteh
# 4303        Roland Emmerich
# 1864           Tarsem Singh
# 73               David Ayer
# 2639          Cameron Crowe
# 1389          Cameron Crowe
# 1789            Burr Steers
# 1041         Neill Blomkamp
# 2327           Angelo Pizzo
# 1788     David Gordon Green
# 1029            Ben Stiller
# 65             Bryan Singer
# 2022         Gavin O'Connor
# 1013     Jaume Collet-Serra
# 1512              Ken Scott
# 1496        Robert Zemeckis
# 380              Jon M. Chu
# 150               Paul Feig
# 1582              Paul Feig
# 1317           Pierre Morel
# 548             Guy Ritchie
# 1010              Gary Ross
# 2099          Paul McGuigan
# 1146          Paul McGuigan
# 264        Robert Schwentke
# 248              Dave Green
# ...

# %% [markdown]
# Fazendo um recorte dos filmes de 2000 até as datas mais recentes do dataset pegando amostra dos 100 primeiros, realmente observamos um queda nos lucros, chegando até ao prejuízo no caso dos filmes mais recentes. Levando em consideração que na base do Kaggle consta que esse dataset foi upado a 2 anos atrás(2018). Se acreditarmos que essas informações foram recolhidas até 2017 e temos muitos filmes de 2015 e 2016 com prejuizo, pode ser realmente que esse prejuizo seja por conta de não ter havido tempo para recuperação de investimentos. Mas não sei se, com apenas essas informações podemos inferir uma relação causal entre tempo e lucro.

# %% [markdown]
# ## Desafio 4 do [Paulo Silveira](https://twitter.com/paulo_caelum)
#
# Quais foram os filmes da decada pré 2° guerra que tiveram muito lucro.

# %%
imdb_usa[["director_name", "movie_title", "title_year", "gross", "budget", "lucro"]].query("title_year>=1937 & title_year<1940").sort_values("lucro", ascending=False).dropna().head(50)
# Out:
#          director_name                       movie_title  title_year  \
# 3970    Victor Fleming               Gone with the Wind       1939.0
# 4449  William Cottrell  Snow White and the Seven Dwarfs       1937.0
# 4157    Victor Fleming                 The Wizard of Oz       1939.0
#
#             gross     budget        lucro
# 3970  198655278.0  3977000.0  194678278.0
# 4449  184925485.0  2000000.0  182925485.0
# 4157   22202612.0  2800000.0   19402612.0

# %% [markdown]
# Observamos os filmes Gone with the Wind e The Wizard of Oz tendo um lucro considerado e no ano que se inicia a 2ª grande guerra. E ambos os filmes são clássicos do cinema até nossos dias.

# %% [markdown]
# ## Desafio 5 do [Paulo Silveira](https://twitter.com/paulo_caelum)
#
# No gráfico de **filmes_irmaos por dindin** temos alguns pontos estranhos entre 15 e 20. Confirme a tese genial do Paulo que o cidadão estranho é o Woody Allen. (Se ele tiver errado pode cornete nas redes sociais kkkkk)

# %%
gross_director.query("filmes_irmaos == 18")
# Out:
#      director_name      dindin  filmes_irmaos
# 1538   Woody Allen   7496522.0           18.0
# 1737   Woody Allen  16684352.0           18.0
# 1861   Woody Allen  13383737.0           18.0
# 1869   Woody Allen  10569071.0           18.0
# 1872   Woody Allen   9714482.0           18.0
# 1960   Woody Allen  33404871.0           18.0
# 1975   Woody Allen  17071230.0           18.0
# 1993   Woody Allen   3203044.0           18.0
# 2070   Woody Allen  14792779.0           18.0
# 2078   Woody Allen   4839383.0           18.0
# 2166   Woody Allen  10763469.0           18.0
# 2183   Woody Allen   5306447.0           18.0
# 2188   Woody Allen   3247816.0           18.0
# 2360   Woody Allen   5032496.0           18.0
# 2932   Woody Allen  39200000.0           18.0
# 3189   Woody Allen         NaN           18.0
# 3191   Woody Allen         NaN           18.0
# 3232   Woody Allen         NaN           18.0

# %% [markdown]
# ## Desafio 6 do [Thiago Gonçalves](https://twitter.com/tgcsantos)
#
# Analise mais detalhadamente o gráfico pairplot, gaste um tempo pensando e tentando enteder os gráficos.

# %% [markdown]
# ## Desafio 7 do [Thiago Gonçalves](https://twitter.com/tgcsantos)
#
# Calcular a correlação apenas dos filmes pós anos 2000 (Jogar fora filmes antes de 2000) e interpretar essa correlação.

# %%
filmes_pos_2000 = imdb_usa[["title_year", "gross", "budget", "lucro"]].query("title_year>=2000")
sns.pairplot(data=filmes_pos_2000[["title_year", "gross", "budget", "lucro"]])

# %%
filmes_pos_2000.corr()
# Out:
#             title_year     gross    budget     lucro
# title_year    1.000000  0.105342  0.058550  0.035039
# gross         0.105342  1.000000  0.709233  0.770642
# budget        0.058550  0.709233  1.000000  0.097307
# lucro         0.035039  0.770642  0.097307  1.000000

# %% [markdown]
# Observamos boa correlação entre lucro e gross, budget e gross e pouca correlação entre lucro e ano, budget e ano.

# %% [markdown]
# ## Desafio 8 do [Allan Spadini](https://twitter.com/allanspadini)
#
# Tentar encontrar uma reta, pode ser com uma régua no monitor (não faça isso), com o excel/google sheets, com o python, no gráfico que parece se aproximar com uma reta (por exemplo budget/lucro, gross/lucro)

# %%
sns.regplot(data=imdb_usa, x="budget", y="lucro")

# %%
sns.lmplot(data=imdb_usa, x="gross", y="lucro")

# %% [markdown]
# ## Desafio 9 da [Thais André](https://twitter.com/thais_tandre)
#
# Analisar e interpretar a correlação de outras variáveis além das feitas em sala (notas é uma boa). Número de avaliações por ano pode ser também uma feature.

# %%
sns.pairplot(data = imdb_usa[["num_voted_users", "imdb_score"]])

imdb_usa[["num_voted_users", "imdb_score"]].corr()
# Out:
#                  num_voted_users  imdb_score
# num_voted_users          1.00000     0.44734
# imdb_score               0.44734     1.00000

# %% [markdown]
# Não notamos uma correção alta entre o numero de usuários que votaram e as notas, observa-se que não chegam a 50% de correlação entre si.
